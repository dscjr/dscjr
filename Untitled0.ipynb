# %% [markdown]
# <a href="https://colab.research.google.com/github/dscjr/dscjr/blob/main/Untitled0.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# -*- coding: utf-8 -*-
import numpy as np
import matplotlib.pyplot as plt
import requests
import time

#from kivy.app import App
#from kivy.lang import Builder



"""
fruits = ["apple", "banana", "cherry", "kiwi", "mango", "abacaxi"]

newlist = [x for x in fruits if "a" or "o" in x]
print(newlist) 




#newlist = [x.upper() for x in newlist]
#print(newlist) 

#newlist = [x.lower() for x in newlist]
#print(newlist)

#newlist = [ "Fruta " + x + " nova!" for x in newlist]
#print(newlist)

preco = 10
calcular_imposto2 = lambda x: x * 0.3
print(calcular_imposto2(preco)+preco)

saldo = "1_000_000"
print(saldo)

saldo2 = saldo.replace("_", ".")
print(saldo2)

saldo2 = saldo.replace(".", "")
saldo3 = int(saldo2) + 300
print(saldo3)

saldo4 = int(saldo) + 300
print(saldo4)


w=30.1
y = 10 if w>20 else 0
print(f"Valor de w={w:.2f} e valor de y={y:.1f}!!!!")


def calcular_impostos():
	print("Funcao calcular impostos")
	print("Uso de funcao")


calcular_impostos()


precos = [100, 200, 300, 400]
impostos = list(map(lambda x: x*0.3, precos))
print(impostos)

impostos2 = [item*0.5 for item in precos]
print(impostos2)

def calcular_impostos4x(precos):
	impostos4 = list(map(lambda x: x*2.5, precos))
	print(impostos4)
	print("Valores calculados com function")
	print("\n")

calcular_impostos4x(precos)


texto2 = " x d b n        dfDD"
print(texto2)
texto3 = texto2.strip()
print(texto3)
texto3 = texto3.strip()
print(texto3)


def tratar_txt(texto):
	texto4 = texto.replace(" ", "")
	print(f"Texto dentro da funcao = {texto4}")
	return texto4

textoy = tratar_txt(texto2)
print(f"Texto fora da funcao = {textoy}")

precos2 = [x * 2 for x in precos]
print(precos2)

print(precos[0])
print(precos2[0])
print("")

class ControleRemoto:
	def __init__(self, cor, altura):
		self.cor = cor
		self.altura = altura
	def copiar_controle(self, controlex, controley):
		self.cor = controlex.cor
		self.altura = controlex.altura

controle_remoto = ControleRemoto("preto", "10")
print(f"Controle 1 = Altura {controle_remoto.altura} e cor {controle_remoto.cor}")
controle_remoto = ControleRemoto("azul", "30")
print(f"Controle 1 = Altura {controle_remoto.altura} e cor {controle_remoto.cor}")
controle_remoto2 = ControleRemoto("amarelo", "99")
print(f"Controle 2 = Altura {controle_remoto2.altura} e cor {controle_remoto2.cor}")
#controle_remoto2 = controle_remoto
#print(f"Altura {controle_remoto2.altura} e cor {controle_remoto2.cor}")

controle_remoto2.copiar_controle(controle_remoto, controle_remoto2)
print(f"Controle 2 = Altura {controle_remoto2.altura} e cor {controle_remoto2.cor} via funcao da classe\n")

"""


# comentario

"""
bloco de
comentario
3 vezes aspas duplas
"""
"""
for i in range(10):
	print(i)

for i in range(10):
	y = 2*i
	print(y)

nomex = "Junior"
for i in nomex:
	print(i.upper())

textoss = "Teste de texto testado e testando"
print(textoss)
textoss1 = textoss.replace(" ","t")
textosslista = textoss1.split("t")
#t.replace("#","")
#textosslista = textosslista.split(" ")
print(textosslista)
textoss = textoss.replace("e","#")
textoss = textoss.replace("#","")
textoss = textoss.replace(" ","")
textoss = textoss.strip()
print(textoss)

#  INPUT
#meutexto = input("Digite um texto:")
#meunumero = int(input("Digite um numero:"))
#print(f"Texto {meutexto} e numero {meunumero}")


# ENUMERATE
print("\nUSANDO ENUMERATE")
for i, nomeen in enumerate(textosslista):
  print(i, nomeen)


#if
#elif
#elif
#elif
#else


#  USO DO TRY / EXCEPT

#try:
#	print(2/0)
#except:
#	print("ERRO!")



listamap = [1, 2, 3, 5, 6, 8, 9, 12]
def dobro(x):
  return x*2
#for i in listamap:
valordobrado = map(dobro, listamap)
#  print()
#for v in valordobrado:
#  print(v)
valordobrado = list(valordobrado)
print(valordobrado)

# FUNCAO REDUCE
from functools import reduce
listareduce = [1, 2, 3, 5, 6, 8, 9, 12]
def soma(x,y):
  return x+y
soma = reduce(soma, listareduce)
print(soma)



# FUNCAO ZIP
listazip1 = [1, 2, 3, 5, 6, 8, 9, 12]
listazip2 = ["apple", "banana", "cherry", "kiwi", "mango", "abacaxi"]
listazip3 = ["a","b","c","d","e","f"]
print(listazip1)
print(listazip2)
print(listazip3)
for numero, fruta, letras in zip(listazip1, listazip2,listazip3):
  print(numero, fruta, letras)

print(listazip2[0][0:3])
print(listazip2[1][0:4])
print(listazip2[3][0:2])
print(listazip2[5][0:5])
print(listazip2[1][1:4])
listaletra = []
for x in listazip2:
   if "a" in x:
    print(f"Existe letra a em {x}")
    listaletra.append(x)
print(f"Lista de letras = {listaletra}")
print(f"A lista tem {len(listaletra)} itens!")
#listaletra.count

listazip4 = ["a","b","c","d","e","f"]
type(listazip4)
isinstance(listazip4,list)

dici = {'Fulano':1, 'Beltrano':2, 'Ciclano':3}
print(dici)
dici.update({'Ana':7})
print(dici)
dici.update({'Zezim':8})
dici.update({'AnaX':10})
print(dici)
print(dici.keys())

import numpy as np

v = np.array([1,3,4,6,8,9])

print(type(v))

for i in v:
  print(v)
  print(v.max)
  print(v.min)

listazip5 = ["a","b","c","d","e","f"]

letrasx = [letra for letra in listazip5]
print(letrasx)

letrasx.reverse()
print(letrasx)
letrasx.sort()
print(letrasx)

k=0
while len(letrasx) > 0:
#  letrasx.remove()
  letrasx.pop(0)
  print(letrasx)

pos=0
while len(listazip5) > len(letrasx):
#  letrasx.remove()
  letrasx.append(listazip5[pos])
  print(letrasx)
  pos+=1

while len(letrasx) > 0:
#  letrasx.remove()
  letrasx.pop(int(len(letrasx))-1)
  print(letrasx)

posx=int(len(listazip5))
while len(listazip5) > len(letrasx):
  posx=posx-1
  letrasx.append(listazip5[posx])
  print(letrasx)

while len(letrasx) > 0:
#  letrasx.remove()
  letrasx.pop(int(len(letrasx))-1)
  print(letrasx)




listazip5 = ["a","b","c","d","e","f"]
for i, letraw in enumerate(listazip5):
  print(f"Item/Letra = {i}/{letraw}")


x = np.linspace(0,20,100)
y = (2**(x/2))
w = (x**2)+2
z = (x*20)
plt.plot(x,z,'*r')
plt.plot(x,w,'.g')
plt.plot(x,y,'.c')
plt.xlabel('Valor de x')
plt.ylabel('y=x**2')
plt.grid(b=None, which='major', axis='both')
plt.title('Grafico funcao')
plt.show()

print('\n')

x=np.linspace(-20,20,200)
y1=x**2
y2=x+4
y3=x+25

#DEFINE QUANTIDADE DE GRAFICOS
fig, janela = plt.subplots(2,2)

janela[0,0].plot(x,y1,'.b')
janela[0,1].plot(x,y2,'.r')
janela[1,0].plot(x,y3,'.c')
janela[1,1].plot(x,x**2,'.y')
fig.legend(['Quadrado', 'mais 4', 'mais 25', 'quadrado'])

plt.show()


"""


cotacoes = []
cotacoesmax = 0
cotacoesmin = 0
qw = 0
amostras = 50
while qw < amostras:
#REQUESTS GET POST PATCH DELETE
  import requests
  import time
  requisicao = requests.get("https://economia.awesomeapi.com.br/last/USD-BRL,EUR-BRL,BTC-BRL")
#print(requisicao)
#CONVERTE JSON RECEBIDO PARA VARIAVEL COTACAO (DICIONARIO)
  cotacaox = requisicao.json()
#print(cotacaox)
#print(cotacaox.get(['USDBRL']['code']))
#  print(f"Cotacao dolar real: {cotacaox['USDBRL']['bid']}")
#  print(f"Cotacao euro real: {cotacaox['EURBRL']['bid']}")
#  print(float(str({cotacaox['EURBRL']['bid']}).replace("{", "").replace("}", "").replace("'", "")))
  cotacoes.append(float(str({cotacaox['EURBRL']['bid']}).replace("{", "").replace("}", "").replace("'", "")))

#print(cotacoes =  enumerate(cotacoes))

  if cotacoesmax != max(cotacoes):
     cotacoesmax = max(cotacoes)
#     print("*******************************")
     print(f"*Cotacao MAXIMA = {cotacoesmax}")
#     print("*******************************")

  if cotacoesmin != min(cotacoes):
     cotacoesmin = min(cotacoes)
#     print("*******************************")
     print(f"*Cotacao MINIMA = {cotacoesmin}")
#     print("*******************************")

#  print(f"Cotacoes em VARIAVEL = {cotacoes}")
  qw = qw + 1
  time.sleep(5)

print(f"***************************************\nCOTACOES EM VARIAVEL = {cotacoes}\n")
cotacoesmax = max(cotacoes)
cotacoesmin = min(cotacoes)
print(f"---> Cotacao final MAXIMA = {cotacoesmax}<---")
print(f"---> Cotacao final MINIMA = {cotacoesmin}<---")
print("\n")

totalcot = len(cotacoes)
print(f"Quantidade de amostras = {totalcot}")

x = np.linspace(0,amostras,totalcot)
y = cotacoes
plt.plot(x,y, linestyle='solid',color='red')

plt.xlabel('')
plt.ylabel('y=cotacao')
plt.grid(b=None, which='major', axis='both')
plt.title('Grafico cotacoes de variavel')
plt.show()

print('\n')


print(" ***** SALVAR EM ARQUIVO TEXTO *****")

#SALVAR ARQUIVO
#O segundo método é o writelines() que recebe um objeto iterável (seja uma lista, uma tupla, um dicionário, etc). 
#O primeiro é o método write() que recebe uma string como parâmetro e a insere no arquivo: 
try:
    extensao = ".txt"
    nome_arquivo = input('Nome do arquivo a ser editado:')
    nome_arquivo = (f"{nome_arquivo}{extensao}")
    print(nome_arquivo)
    arquivo = open(nome_arquivo, 'r+')
except FileNotFoundError:
    arquivo = open(nome_arquivo, 'w+')
    arquivo.writelines(u'')
#faca o que quiser
#arquivo.write("Cotacoes/cotacoes maximas/cotacoes minimas\n")
#arquivo.write(f"Cotacoes = {cotacoes}\n")
#arquivo.write(f"Maxima = {cotacoesmax}\n")
#arquivo.write(f"Minima = {cotacoesmin}\n")
#arquivo.write(f"Amostras = {len(cotacoes)}\n")
arquivo.write(f"{cotacoes}\n")
arquivo.write(f"{cotacoesmax}\n")
arquivo.write(f"{cotacoesmin}\n")
arquivo.write(f"{len(cotacoes)}\n")

arquivo.close()
time.sleep(5)


print(" ***** LER DE ARQUIVO TEXTO *****")

#ABRIR ARQUIVO
try:
  arquivo = open(nome_arquivo, "r")
#print(arquivo.readlines())
#  for line in arquivo:
#    print(line)
#for i, letraw in enumerate(listazip5):
#  print(f"Item/Letra = {i}/{letraw}")
  linhas = arquivo.readlines()

#arq = open("meu_arquivo.txt")
#linhas = arq.readlines()
#for linha in linhas:
#    print(linha)

  cotacoesxyz = []
  cotacoesxyz2 = []

  for i, line in enumerate(linhas):
    if i==0:
      txttemp = line.replace("[","").replace("]","").replace(" ","").replace("\n","").replace("'","")
#      print("Replace concluido")
#      print(txttemp)
      cotacoesxyz = txttemp.split(',')
#      print("Split concluido")
#      print(cotacoesxyz)
      cotacoesxyz2 = list(map(float, cotacoesxyz))

#      print("Float concluido pelo map")
#      print(f"{i}-{cotacoesxyz}")
      print(f"Cotacoes no arquito = {cotacoesxyz2}")
    if i==1: 
      cotacoesmax = float(line)
      print(f"Cotacao maxima no arquivo = {cotacoesmax}")
    if i==2: 
      cotacoesmin = float(line)
      print(f"Cotacao minima no arquivo = {cotacoesmin}")
    if i==3: 
      tamanho = int(line)
      print(f"Amostras no arquivo = {tamanho}")
  arquivo.close()
except:
  print("Nao foi possivel abrir o arquivo")


#cotacoes
#cotacoesmax
#cotacoesmin
#len(cotacoes)

x = np.linspace(0,tamanho,tamanho)
y = cotacoesxyz2
plt.plot(x,y, linestyle='solid',color='red')

x = np.linspace(0,amostras,totalcot)
y = cotacoes
plt.plot(x,y, linestyle='solid',color='red')


plt.xlabel('')
plt.ylabel('y=cotacao')
plt.grid(b=None, which='major', axis='both')
plt.title('Grafico cotacoes de ARQUIVO')
plt.show()
# Out:
# *Cotacao MAXIMA = 5.1296
# *Cotacao MINIMA = 5.1296
# *Cotacao MAXIMA = 5.1319
# *Cotacao MAXIMA = 5.133
# *Cotacao MAXIMA = 5.1334
# ***************************************
# COTACOES EM VARIAVEL = [5.1296, 5.1296, 5.1296, 5.1296, 5.1296, 5.1296, 5.1296, 5.1296, 5.1319, 5.1319, 5.1319, 5.1319, 5.1319, 5.1319, 5.1319, 5.1319, 5.1319, 5.1319, 5.133, 5.1319, 5.1319, 5.133, 5.133, 5.133, 5.133, 5.133, 5.133, 5.133, 5.133, 5.133, 5.133, 5.133, 5.133, 5.133, 5.133, 5.133, 5.133, 5.133, 5.133, 5.133, 5.133, 5.133, 5.1334, 5.1334, 5.1334, 5.1334, 5.1334, 5.1334, 5.1334, 5.1334]
#
# ---> Cotacao final MAXIMA = 5.1334<---
# ---> Cotacao final MINIMA = 5.1296<---
#
#
# Quantidade de amostras = 50
#  ***** SALVAR EM ARQUIVO TEXTO *****
# Nome do arquivo a ser editado:teste4
# teste4.txt
#  ***** LER DE ARQUIVO TEXTO *****
# ...
